# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_formats = {'svg',}

# %%
picked_mode = pd.read_csv('picked_mode.dat', skiprows=5, delim_whitespace=True, dtype='float')
picked_mode2 = pd.read_csv('picked_mode2.dat', skiprows=5, delim_whitespace=True, dtype='float')
picked_mode.columns = picked_mode2.columns
picked_mode = picked_mode.ix[picked_mode['t_step']>=2602000.]
picked_mode.reset_index(inplace=True, drop=True)
picked_mode = picked_mode.append(picked_mode2)
picked_mode.reset_index(drop=True, inplace=True)

# %%
picked_mode.tail()
# Out:
#            t_step  time  radius_ID    radius  degree  order  velocity_pol  \
# 386152  3000000.0   1.5       93.0  1.534184     0.0    0.0           0.0
# 386153  3000000.0   1.5       94.0  1.536054     0.0    0.0           0.0
# 386154  3000000.0   1.5       95.0  1.537391     0.0    0.0           0.0
# 386155  3000000.0   1.5       96.0  1.538194     0.0    0.0           0.0
# 386156  3000000.0   1.5       97.0  1.538462     0.0    0.0           0.0
#
#         velocity_tor  velocity_pol_dr  temperature  pressure  vorticity_pol  \
# 386152           0.0              0.0     0.015722  0.320734            0.0
# 386153           0.0              0.0     0.008863  0.119726            0.0
# 386154           0.0              0.0     0.003942  0.022181            0.0
# 386155           0.0              0.0     0.000986 -0.000669            0.0
# 386156           0.0              0.0     0.000000  0.000000            0.0
#
#         vorticity_tor  vorticity_pol_dr  magnetic_field_pol  \
# 386152            0.0               0.0                 0.0
# 386153            0.0               0.0                 0.0
# 386154            0.0               0.0                 0.0
# 386155            0.0               0.0                 0.0
# 386156            0.0               0.0                 0.0
#
#         magnetic_field_tor  magnetic_field_pol_dr  grad_temp_pol  \
# 386152                 0.0                    0.0      -8.593210
# 386153                 0.0                    0.0      -8.671503
# 386154                 0.0                    0.0      -8.701895
# 386155                 0.0                    0.0      -8.713410
# 386156                 0.0                    0.0      -8.716711
#
#         grad_temp_tor  grad_temp_pol_dr
# 386152            0.0          0.007861
# 386153            0.0          0.004432
# 386154            0.0          0.001971
# 386155            0.0          0.000493
# 386156            0.0          0.000000

# %%
source = 1.0 # is this what I want??
nr = 97
ilevel = picked_mode.ix[:, 2]
radius = picked_mode.ix[0:96, 3]
temp = picked_mode.ix[:, 9]
flux = picked_mode.ix[:, 17]
nentry = len(ilevel)

# %%
Tavg = dict()
qavg = dict()

# %%
for i in range(1, 98):
    Tavg[i] = 0
    qavg[i] = 0

# %%
for k in range(0,nentry):
    Tavg[int(ilevel[k])] += float(temp[k])
    qavg[int(ilevel[k])] += float(flux[k])

# %%
navg = nentry/ nr
for i in Tavg.keys():
    Tavg[i] = Tavg[i]/navg
    qavg[i] = qavg[i]/navg

# %%
Trms = 0
for i in range(0, 96):
    ravg = 0.5 * (float(radius[i]) + float(radius[i+1]))
    dr = float(radius[i+1]) - float(radius[i])
    Tbar = 0.5 * (Tavg[int(ilevel[i])] + Tavg[int(ilevel[i])+1])
    Trms = Trms + 4 * np.pi * ravg**2 * dr * Tbar**2
    
V = 4 * np.pi * (float(radius[96])**3 - float(radius[0])**3)/3
Trms/V
# Out:
# 0.08059731398668553

# %%
plt.plot(radius.tolist(), list(Tavg.values()))
plt.xlabel('Radius')
plt.ylabel('Temperature')
plt.show()

# %%
cdim = radius[0]/radius[nr-1]
qb2 = source * (radius[nr-1]**2)/6
r2 = radius**2
tmp = 1 - cdim
c1 = radius[0]*(1 - qb2*(1 - cdim**2))/(1 - cdim)
c2 = qb2 - c1/radius[nr-1]
Tc = (c1/radius) + c2 - (source/6)*r2

# %%
plt.plot(Tc.index.tolist(), Tc.values.tolist())
plt.show()

# %%
Tc
# Out:
# 0     1.000000e+00
# 1     9.994521e-01
# 2     9.978117e-01
# 3     9.950891e-01
# 4     9.913011e-01
# 5     9.864707e-01
# 6     9.806270e-01
# 7     9.738044e-01
# 8     9.660423e-01
# 9     9.573842e-01
# 10    9.478773e-01
# 11    9.375717e-01
# 12    9.265196e-01
# 13    9.147750e-01
# 14    9.023925e-01
# 15    8.894271e-01
# 16    8.759334e-01
# 17    8.619651e-01
# 18    8.475749e-01
# 19    8.328133e-01
# 20    8.177292e-01
# 21    8.023688e-01
# 22    7.867761e-01
# 23    7.709923e-01
# 24    7.550557e-01
# 25    7.390020e-01
# 26    7.228640e-01
# 27    7.066716e-01
# 28    6.904523e-01
# 29    6.742306e-01
#           ...
# 67    1.550681e-01
# 68    1.452279e-01
# 69    1.356507e-01
# 70    1.263434e-01
# 71    1.173128e-01
# 72    1.085659e-01
# 73    1.001097e-01
# 74    9.195114e-02
# 75    8.409711e-02
# 76    7.655453e-02
# 77    6.933016e-02
# 78    6.243067e-02
# 79    5.586258e-02
# 80    4.963224e-02
# 81    4.374577e-02
# 82    3.820910e-02
# 83    3.302789e-02
# 84    2.820752e-02
# 85    2.375307e-02
# 86    1.966930e-02
# 87    1.596063e-02
# 88    1.263112e-02
# 89    9.684448e-03
# 90    7.123891e-03
# 91    4.952328e-03
# 92    3.172210e-03
# 93    1.785561e-03
# 94    7.939622e-04
# 95    1.985475e-04
# 96    5.551115e-17
# Name: radius, dtype: float64
